# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data =  pd.read_csv('tested.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
import pandas as pd
import numpy as np
from pandas_profiling import ProfileReport

profile = ProfileReport(data)
profile.to_file(output_file = 'Titanic_Report.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 413        False     False   False  False  False   True  False  False   False
# 414        False     False   False  False  False  False  False  False   False
# 415        False     False   False  False  False  False  False  False   False
# 416        False     False   False  False  False   True  False  False   False
# 417        False     False   False  False  False   True  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
data.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin           True
# Embarked       False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
data.shape
# Out:
# (418, 12)

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data['Name']
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
df = pd.DataFrame(data)

# %%
df['Sex']
# Out:
# 0        male
# 1      female
# 2        male
# 3        male
# 4      female
#         ...
# 413      male
# 414    female
# 415      male
# 416      male
# 417      male
# Name: Sex, Length: 418, dtype: object

# %% [markdown]
# For Unique Values

# %%
data.nunique()
# Out:
# PassengerId    418
# Survived         2
# Pclass           3
# Name           418
# Sex              2
# Age             79
# SibSp            7
# Parch            8
# Ticket         363
# Fare           169
# Cabin           76
# Embarked         3
# dtype: int64

# %%
data['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
data['Sex'].nunique()
# Out:
# 2

# %%
data['Parch'].unique()
# Out:
# array([0, 1, 3, 2, 4, 6, 5, 9], dtype=int64)

# %% [markdown]
# Cleaning the Data

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# How to get row

# %%
print(data.loc[4]) 

# how to display location 4 rows

print("   ")
type(data.loc[4])
# Out:
# PassengerId                                             896
# Survived                                                  1
# Pclass                                                    3
# Name           Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# Sex                                                  female
# Age                                                    22.0
# SibSp                                                     1
# Parch                                                     1
# Ticket                                              3101298
# Fare                                                12.2875
# Cabin                                                   NaN
# Embarked                                                  S
# Name: 4, dtype: object
# pandas.core.series.Series

# %%
#data.loc(PassengerId[896] )
PassengerId_1 = data['PassengerId']
PassengerId_1.loc[4]
# Out:
# 896

# %%
data.loc[90:100]        # how to get custom rows from data
# Out:
#      PassengerId  Survived  Pclass  \
# 90           982         1       3
# 91           983         0       3
# 92           984         1       1
# 93           985         0       3
# 94           986         0       1
# 95           987         0       3
# 96           988         1       1
# 97           989         0       3
# 98           990         1       3
# 99           991         0       3
# 100          992         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 90   Dyker, Mrs. Adolf Fredrik (Anna Elisabeth Judi...  female  22.0      1
# 91                                  Pedersen, Mr. Olaf    male   NaN      0
# 92                Davidson, Mrs. Thornton (Orian Hays)  female  27.0      1
# 93                                   Guest, Mr. Robert    male   NaN      0
# 94                                 Birnbaum, Mr. Jakob    male  25.0      0
# 95                          Tenglin, Mr. Gunnar Isidor    male  25.0      0
# ...

# %%
data.sample(5)         # sample function get random rows from the dataa
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 193         1085         0       2                Lingane, Mr. John    male
# 53           945         1       1       Fortune, Miss. Ethel Flora  female
# 190         1082         0       2             Angle, Mr. William A    male
# 196         1088         0       1  Spedden, Master. Robert Douglas    male
# 385         1277         1       2               Herman, Miss. Kate  female
#
#       Age  SibSp  Parch  Ticket    Fare        Cabin Embarked
# 193  61.0      0      0  235509   12.35          NaN        Q
# 53   28.0      3      2   19950  263.00  C23 C25 C27        S
# 190  34.0      1      0  226875   26.00          NaN        S
# 196   6.0      0      2   16966  134.50          E34        C
# 385  24.0      1      2  220845   65.00          NaN        S

# %%
data.at[190, 'Fare']               # at method reterive single value in special index and columns
# Out:
# 26.0

# %%
print(data.Fare.sum())
print("")                          # how to get custom column and find its mean, max, min etc
print(data.Fare.mean())
print("")
print(data.Fare.max())
print("")
print(data.Fare.min())
print("")
print(data.Fare.count())
print("")
print(data.Fare.std())
# Out:
# 14856.5376
#
# 35.6271884892086
#
# 512.3292
#
# 0.0
#
# 417
#
# 55.90757617997383

# %%
data.plot('Age')
plt.show()

# %%
data.Age.plot();
plt.show()

# %%
data.Age.plot();
data.Fare.plot();
plt.show()

# %%
sns.scatterplot(data.Age, data.Fare)
plt.show()
# Out:
# C:\Users\Engr Saeed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
data['PassengerId'].unique
# Out:
# <bound method Series.unique of 0       892
# 1       893
# 2       894
# 3       895
# 4       896
#        ...
# 413    1305
# 414    1306
# 415    1307
# 416    1308
# 417    1309
# Name: PassengerId, Length: 418, dtype: int64>

# %%
numeric = df._get_numeric_data().columns       # how to get numeric columns
numeric = df._get_numeric_data().columns
print(numeric)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
stri = df.select_dtypes(["string"]).columns
stri
# Out:
# Index([], dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# Drop Some Columns

# %%
import pandas

sex = pandas.get_dummies(df['Sex'])           
sex.head()
data = pd.concat([df,sex], axis = 1)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked  female  male
# 0   330911   7.8292   NaN        Q       0     1
# 1   363272   7.0000   NaN        S       1     0
# 2   240276   9.6875   NaN        Q       0     1
# 3   315154   8.6625   NaN        S       0     1
# 4  3101298  12.2875   NaN        S       1     0

# %%
data.drop(['Name', 'Sex', 'Cabin'], inplace = True, axis = 1)   # Drop Name , Sex and Cabin
data.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch   Ticket     Fare  \
# 0          892         0       3  34.5      0      0   330911   7.8292
# 1          893         1       3  47.0      1      0   363272   7.0000
# 2          894         0       2  62.0      0      0   240276   9.6875
# 3          895         0       3  27.0      0      0   315154   8.6625
# 4          896         1       3  22.0      1      1  3101298  12.2875
#
#   Embarked  female  male
# 0        Q       0     1
# 1        S       1     0
# 2        Q       0     1
# 3        S       0     1
# 4        S       1     0

# %%
data.drop(['Embarked'], inplace = True, axis= 1)      #  Drop Embarked
data.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch   Ticket     Fare  \
# 0          892         0       3  34.5      0      0   330911   7.8292
# 1          893         1       3  47.0      1      0   363272   7.0000
# 2          894         0       2  62.0      0      0   240276   9.6875
# 3          895         0       3  27.0      0      0   315154   8.6625
# 4          896         1       3  22.0      1      1  3101298  12.2875
#
#    female  male
# 0       0     1
# 1       1     0
# 2       0     1
# 3       0     1
# 4       1     0

# %%
print(data.Ticket.value_counts())
# Out:
# PC 17608    5
# CA. 2343    4
# 113503      4
# PC 17483    3
# 220845      3
#            ..
# 349226      1
# 2621        1
# 4133        1
# 113780      1
# 2668        1
# Name: Ticket, Length: 363, dtype: int64

# %%
print(data.male.value_counts())
# Out:
# 1    266
# 0    152
# Name: male, dtype: int64

# %%
print(data.Age.value_counts())
# Out:
# 21.0    17
# 24.0    17
# 22.0    16
# 30.0    15
# 18.0    13
#         ..
# 76.0     1
# 28.5     1
# 22.5     1
# 62.0     1
# 38.5     1
# Name: Age, Length: 79, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Age          332 non-null    float64
#  4   SibSp        418 non-null    int64
#  5   Parch        418 non-null    int64
#  6   Ticket       418 non-null    object
#  7   Fare         417 non-null    float64
#  8   female       418 non-null    uint8
#  9   male         418 non-null    uint8
# dtypes: float64(2), int64(5), object(1), uint8(2)
# memory usage: 27.1+ KB

# %%
data.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# female         False
# male           False
# dtype: bool

# %%
data['Fare'].isnull().any()      # checking missing vale from columns
#data['Age']
# Out:
# True

# %%
# Fill the Null Values

# %%
data['Age'].fillna(0, inplace = True)
data.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch   Ticket     Fare  \
# 0          892         0       3  34.5      0      0   330911   7.8292
# 1          893         1       3  47.0      1      0   363272   7.0000
# 2          894         0       2  62.0      0      0   240276   9.6875
# 3          895         0       3  27.0      0      0   315154   8.6625
# 4          896         1       3  22.0      1      1  3101298  12.2875
#
#    female  male
# 0       0     1
# 1       1     0
# 2       0     1
# 3       0     1
# 4       1     0

# %%
data['Age'].isnull().any()
# Out:
# False

# %%
data['Fare'].fillna(0, inplace = True)
data.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch   Ticket     Fare  \
# 0          892         0       3  34.5      0      0   330911   7.8292
# 1          893         1       3  47.0      1      0   363272   7.0000
# 2          894         0       2  62.0      0      0   240276   9.6875
# 3          895         0       3  27.0      0      0   315154   8.6625
# 4          896         1       3  22.0      1      1  3101298  12.2875
#
#    female  male
# 0       0     1
# 1       1     0
# 2       0     1
# 3       0     1
# 4       1     0

# %%
data.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# female         False
# male           False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# female         0
# male           0
# dtype: int64

# %% [markdown]
# # Relationship Analysis

# %% [markdown]
# Co-Relation matrix,
# corelation is a Table,
# corelation is used to summarise Data,
# relationship between variaables

# %%
corelation = data.corr()

# %% [markdown]
# creating heatmap of data

# %%
import seaborn as sns

sns.heatmap(corelation, xticklabels = corelation.columns , yticklabels = corelation.columns  )
plt.show()

# %%
sns.scatterplot(data.Age, data.Fare)       # scatterplot for floting point value
plt.show()
# Out:
# C:\Users\Engr Saeed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(data)
plt.show()

# %% [markdown]
# Scatter Plot or Relational Plot

# %%
sns.distplot(data['Age'])
plt.show()
# Out:
# C:\Users\Engr Saeed\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data['Pclass'])
plt.show()

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'female', 'male'],
#       dtype='object')

# %%
sns.distplot(data['Fare'])
plt.show()
# Out:
# C:\Users\Engr Saeed\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(data['PassengerId'])       #  'DisPLot' the passengerId
plt.show()

# %%
sns.displot(data['male'])             #  'DisPlot' the male data
plt.show()

# %%
sns.histplot(data['female'])    #  'Histplot'  the male data
plt.show()

# %%
sns.distplot(data['Parch'])
plt.show()
# Out:
# C:\Users\Engr Saeed\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.catplot(x = 'Age', kind = 'box', data = data)
plt.show()

# %%
sns.catplot(x = 'Fare', kind = 'box', data= data)
plt.show()

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch   Ticket     Fare  \
# 0          892         0       3  34.5      0      0   330911   7.8292
# 1          893         1       3  47.0      1      0   363272   7.0000
# 2          894         0       2  62.0      0      0   240276   9.6875
# 3          895         0       3  27.0      0      0   315154   8.6625
# 4          896         1       3  22.0      1      1  3101298  12.2875
#
#    female  male
# 0       0     1
# 1       1     0
# 2       0     1
# 3       0     1
# 4       1     0

# %%
x = data['male']
y = data['female']

plt.bar(x, y, color = 'blue')
plt.show()

# %%
x = data['PassengerId']
y = data['Fare']

plt.bar(x, y , color = 'pink')
plt.xlabel = ("PassengerId")
plt.ylabel = ("Fare")

plt.show()

# %%
x = data['PassengerId']
y = data['Fare']
x1 =  (x,y)
plt.hist(x1)
plt.show()

# %%
import seaborn as sns

sns.factorplot('Fare', data = data, kind = 'count')
plt.show()

# %%
import seaborn as sns

sns.factorplot('Pclass', data = data, kind = 'count')
plt.show()
# Out:
# C:\Users\Engr Saeed\anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Engr Saeed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data.isnull().values.sum()
# Out:
# 0

# %%
data.isnull().values.any()
# Out:
# False

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

corr= data.corr()
plt.figure(figsize =(5,5))

sns.heatmap(corr,vmax=.8, linewidths = 0.01, square = True, cmap = 'Blues', linecolor = 'white' )
plt.title('corelation between features')
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

corr= data.corr()
plt.figure(figsize =(4,4))

sns.heatmap(corr,vmax=.7, linewidths = 0.01, square = True, cmap = 'YlGnBu', linecolor = 'white' )
plt.title('corelation between features')
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

corr= data.corr()
plt.figure(figsize =(5,5))

sns.heatmap(corr,vmax=.7, linewidths = 0.01, square = True, cmap = 'Greens', linecolor = 'white' )
plt.title('corelation between features')
plt.show()

# %%
plt.figure(figsize=(7,4))
plt.hist(data['Fare'])

#plt.title('Speed Distribution')
#plt.xlabel('Speed')

plt.show()

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch   Ticket     Fare  \
# 0          892         0       3  34.5      0      0   330911   7.8292
# 1          893         1       3  47.0      1      0   363272   7.0000
# 2          894         0       2  62.0      0      0   240276   9.6875
# 3          895         0       3  27.0      0      0   315154   8.6625
# 4          896         1       3  22.0      1      1  3101298  12.2875
#
#    female  male
# 0       0     1
# 1       1     0
# 2       0     1
# 3       0     1
# 4       1     0

# %%
plt.figure(figsize=(7,4))
plt.hist(data['Parch'])

#plt.title('Speed Distribution')
#plt.xlabel('Speed')

plt.show()

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch   Ticket     Fare  \
# 0          892         0       3  34.5      0      0   330911   7.8292
# 1          893         1       3  47.0      1      0   363272   7.0000
# 2          894         0       2  62.0      0      0   240276   9.6875
# 3          895         0       3  27.0      0      0   315154   8.6625
# 4          896         1       3  22.0      1      1  3101298  12.2875
#
#    female  male
# 0       0     1
# 1       1     0
# 2       0     1
# 3       0     1
# 4       1     0
